# %% [markdown]
# **Copyright © 2025 Raphael Senn. Licensed under the MIT License.**
#
# **Author:** Raphael Senn (<raphaelsenn@gmx.de>)
#
# # Generative Adversarial Networks (Goodfellow et al., 2014)

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader

from torchvision.transforms import transforms
from torchvision.datasets import MNIST

from src.gan_fc import (
    Generator,
    Discriminator,
)

from src.objective import (
    GeneratorLoss,
    DiscriminatorLoss
)

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# #### Exploring the training dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                      # pixel transform: img.range[0, 255] -> img.range[0, 1]
    transforms.Lambda(lambda x: x.view(-1))     # shape transfrom: img.shape[1, 28, 28] -> img.shape[1, 784]
])

dataset = MNIST(root='./MNIST/', train=True, download=True, transform=transform)

# %% [markdown]
# #### Visualizing the Training Data

# %%
FIGSIZE = (12, 12)
IMAGE_SHAPE = (28, 28)
N_ROWS, N_COLS = 8, 8

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()

for i in range(N_ROWS * N_COLS):
    img, _ = dataset[i]
    img = img.reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training Setup

# %%
if torch.cuda.is_available(): 
    torch.cuda.manual_seed(SEED)
    device = torch.device('cuda')
elif torch.backends.mps.is_available(): 
    device = torch.device('mps')
else: 
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: mps

# %%
# Create generator and discriminator
DIM_NOISE = 100
generator = Generator(DIM_NOISE).to(device)
discriminator = Discriminator().to(device)

# Hyperparameters
EPOCHS = 100
BATCH_SIZE = 128
SHUFFLE = True

LR_G = 0.002
LR_D = 0.002

BETAS_G = (0.5, 0.999)
BETAS_D = (0.5, 0.999)

# Create the optimizer and the loss
criterion_g = GeneratorLoss()
optimizer_g = torch.optim.Adam(params=generator.parameters(), lr=LR_G, betas=BETAS_G)

criterion_d = DiscriminatorLoss()
optimizer_d = torch.optim.Adam(params=discriminator.parameters(), lr=LR_D, betas=BETAS_D)

# Load the dataset
dataloader = DataLoader(dataset, BATCH_SIZE, SHUFFLE)

# %%
num_params_g = sum(p.numel() for p in generator.parameters())
num_params_d = sum(p.numel() for p in discriminator.parameters())
print(f'Generator has: {num_params_g} learnable parameters')
print(f'Discrimintor has: {num_params_d} learnable parameters')
# Out:
# Generator has: 2503984 learnable parameters
# Discrimintor has: 1231441 learnable parameters

# %%
# Print settings
VERBOSE = True

# Plot settings
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
Z_probs = torch.rand(size=(1000, DIM_NOISE), device=device) * 2 - 1
PLOTTING = True
SAVE_LOC = './mnist_fake'

if PLOTTING:
    if not os.path.exists(SAVE_LOC):
        os.mkdir(SAVE_LOC)

# %% [markdown]
# #### Start Training

# %%
losses_d, losses_g = [], []
N_samples = len(dataset)
for epoch in range(EPOCHS):

    total_loss_g, total_loss_d = 0.0, 0.0
    for x, _ in dataloader:
        # x is sampled from data generating distribution x ~ p_data
        x = x.to(device)

        # z is sampled from noise prior z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1

        with torch.no_grad():
            G_z = generator(z) 
        
        D_x = discriminator(x)
        D_G_z = discriminator(G_z)

        # update descriminator by ascending its stochastic gradient
        optimizer_d.zero_grad()
        loss_d = criterion_d(D_x, D_G_z)
        loss_d.backward()
        optimizer_d.step()
        
        # z is sampled from noise prior
        # z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1
        D_G_z = discriminator(generator(z))

        # update generator by descending its stochastic gradient
        optimizer_g.zero_grad()
        loss_g = criterion_g(D_G_z)
        loss_g.backward()
        optimizer_g.step()

        total_loss_d += loss_d.item() * x.shape[0]
        total_loss_g += loss_g.item() * z.shape[0]
    
    
    losses_d.append(total_loss_d / N_samples)
    losses_g.append(total_loss_g / N_samples)

    if VERBOSE: 
        print(
            f'epoch: {epoch}\t' 
            f'generator loss: {(total_loss_g/N_samples):.4f}\t'
            f'discriminator loss: {(total_loss_d/N_samples):.4f}'
        )

    if PLOTTING:
        G_z = generator(Z)
        fig, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
        ax = ax.flatten()
        for i in range(N_ROWS * N_COLS):
            img = G_z[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
            ax[i].imshow(img, cmap='gray')
            ax[i].axis('off')
        fig.tight_layout()
        fig.savefig(os.path.join(SAVE_LOC, f'mnist_{epoch}'))
        plt.close(fig)
# Out:
# epoch: 0	generator loss: 2.8136	discriminator loss: 0.8556
# epoch: 1	generator loss: 1.9819	discriminator loss: 0.8920
# epoch: 2	generator loss: 1.4125	discriminator loss: 1.0774
# epoch: 3	generator loss: 1.1770	discriminator loss: 1.1739
# epoch: 4	generator loss: 1.0633	discriminator loss: 1.2271
# epoch: 5	generator loss: 0.9920	discriminator loss: 1.2628
# epoch: 6	generator loss: 0.9594	discriminator loss: 1.2816
# epoch: 7	generator loss: 0.9624	discriminator loss: 1.2875
# epoch: 8	generator loss: 0.9530	discriminator loss: 1.2894
# epoch: 9	generator loss: 0.9749	discriminator loss: 1.2800
# epoch: 10	generator loss: 0.9897	discriminator loss: 1.2761
# epoch: 11	generator loss: 1.0013	discriminator loss: 1.2696
# epoch: 12	generator loss: 1.0302	discriminator loss: 1.2562
# epoch: 13	generator loss: 1.0358	discriminator loss: 1.2526
# epoch: 14	generator loss: 1.0491	discriminator loss: 1.2459
# epoch: 15	generator loss: 1.0686	discriminator loss: 1.2366
# epoch: 16	generator loss: 1.0680	discriminator loss: 1.2314
# epoch: 17	generator loss: 1.0629	discriminator loss: 1.2370
# epoch: 18	generator loss: 1.0614	discriminator loss: 1.2377
# epoch: 19	generator loss: 1.0683	discriminator loss: 1.2339
# epoch: 20	generator loss: 1.0891	discriminator loss: 1.2268
# epoch: 65	generator loss: 1.3363	discriminator loss: 1.1328
# epoch: 66	generator loss: 1.3314	discriminator loss: 1.1315
# epoch: 67	generator loss: 1.3362	discriminator loss: 1.1366
# epoch: 68	generator loss: 1.3323	discriminator loss: 1.1421
# epoch: 69	generator loss: 1.3332	discriminator loss: 1.1291
# epoch: 70	generator loss: 1.3241	discriminator loss: 1.1412
# epoch: 71	generator loss: 1.3273	discriminator loss: 1.1371
# epoch: 72	generator loss: 1.3155	discriminator loss: 1.1389
# epoch: 73	generator loss: 1.3173	discriminator loss: 1.1365
# epoch: 74	generator loss: 1.3330	discriminator loss: 1.1326
# epoch: 75	generator loss: 1.3323	discriminator loss: 1.1319
# epoch: 76	generator loss: 1.3303	discriminator loss: 1.1373
# epoch: 77	generator loss: 1.3068	discriminator loss: 1.1508
# epoch: 78	generator loss: 1.3228	discriminator loss: 1.1454
# epoch: 79	generator loss: 1.3338	discriminator loss: 1.1374
# epoch: 80	generator loss: 1.3321	discriminator loss: 1.1305
# epoch: 81	generator loss: 1.3361	discriminator loss: 1.1349
# epoch: 82	generator loss: 1.3493	discriminator loss: 1.1261
# epoch: 83	generator loss: 1.3441	discriminator loss: 1.1285
# epoch: 84	generator loss: 1.3523	discriminator loss: 1.1290
# epoch: 85	generator loss: 1.3229	discriminator loss: 1.1298
# epoch: 86	generator loss: 1.3309	discriminator loss: 1.1306
# epoch: 87	generator loss: 1.3432	discriminator loss: 1.1269
# epoch: 88	generator loss: 1.3457	discriminator loss: 1.1270
# epoch: 89	generator loss: 1.3342	discriminator loss: 1.1262
# epoch: 90	generator loss: 1.3463	discriminator loss: 1.1283
# epoch: 91	generator loss: 1.3337	discriminator loss: 1.1264
# epoch: 92	generator loss: 1.3477	discriminator loss: 1.1276
# epoch: 93	generator loss: 1.3342	discriminator loss: 1.1278
# epoch: 94	generator loss: 1.3361	discriminator loss: 1.1252
# epoch: 95	generator loss: 1.3441	discriminator loss: 1.1287
# epoch: 96	generator loss: 1.3368	discriminator loss: 1.1327
# epoch: 97	generator loss: 1.3464	discriminator loss: 1.1254
# epoch: 98	generator loss: 1.3352	discriminator loss: 1.1285
# epoch: 99	generator loss: 1.3350	discriminator loss: 1.1223

# %% [markdown]
# #### GAN Training Losses

# %%
_, ax = plt.subplots()
ax.plot(np.arange(len(losses_g)), losses_g, label='Generator loss')
ax.plot(np.arange(len(losses_d)), losses_d, label='Discriminator loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Generating Fake Data

# %%
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
data_fake = generator(Z)

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()
for i in range(N_ROWS * N_COLS):
    img = data_fake[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()
