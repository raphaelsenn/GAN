# %% [markdown]
# **Copyright © 2025 Raphael Senn. Licensed under the MIT License.**
#
# **Author:** Raphael Senn (<raphaelsenn@gmx.de>)
#
# # Generative Adversarial Networks (Goodfellow et al., 2014)

# %%
import os

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader

from torchvision.transforms import transforms
from torchvision.datasets import MNIST

from src.gan_mnist import (
    Generator,
    Discriminator,
)

from src.objective import (
    GeneratorLoss,
    DiscriminatorLoss
)

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# #### Exploring the training dataset

# %%
transform = transforms.Compose([
    transforms.ToTensor(),                      # pixel transform: img.range[0, 255] -> img.range[0, 1]
    transforms.Lambda(lambda x: x.view(-1))     # shape transfrom: img.shape[1, 28, 28] -> img.shape[1, 784]
])

dataset = MNIST(root='./MNIST/', train=True, download=True, transform=transform)

# %% [markdown]
# #### Visualizing the Training Data

# %%
FIGSIZE = (16, 16)
IMAGE_SHAPE = (28, 28)
N_ROWS, N_COLS = 8, 8

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()

for i in range(N_ROWS * N_COLS):
    img, _ = dataset[i]
    img = img.reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Training Setup

# %%
if torch.cuda.is_available(): 
    torch.cuda.manual_seed(SEED)
    device = torch.device('cuda')
elif torch.backends.mps.is_available(): 
    device = torch.device('mps')
else: 
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: mps

# %%
# Create generator and discriminator
DIM_NOISE = 100
generator = Generator(DIM_NOISE).to(device)
discriminator = Discriminator().to(device)

# Hyperparameters
EPOCHS = 100
BATCH_SIZE = 128
SHUFFLE = True

LR_G = 0.002
LR_D = 0.002

BETAS_G = (0.5, 0.999)
BETAS_D = (0.5, 0.999)

# Create the optimizer and the loss
criterion_g = GeneratorLoss(maximize=True)
optimizer_g = torch.optim.Adam(params=generator.parameters(), lr=LR_G, betas=BETAS_G, maximize=True)

criterion_d = DiscriminatorLoss()
optimizer_d = torch.optim.Adam(params=discriminator.parameters(), lr=LR_D, betas=BETAS_D, maximize=True)

# Load the dataset
dataloader = DataLoader(dataset, BATCH_SIZE, SHUFFLE)

# %%
num_params_g = sum(p.numel() for p in generator.parameters())
num_params_d = sum(p.numel() for p in discriminator.parameters())
print(f'Generator has: {num_params_g} learnable parameters')
print(f'Discrimintor has: {num_params_d} learnable parameters')
# Out:
# Generator has: 2503984 learnable parameters
# Discrimintor has: 1231441 learnable parameters

# %%
# Print settings
VERBOSE = True

# Plot settings
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
Z_probs = torch.rand(size=(1000, DIM_NOISE), device=device) * 2 - 1
PLOTTING = True
SAVE_LOC = './mnist_fake'

if PLOTTING:
    if not os.path.exists(SAVE_LOC):
        os.mkdir(SAVE_LOC)

# %% [markdown]
# #### Start Training

# %%
losses_d, losses_g = [], []
N_samples = len(dataset)
for epoch in range(EPOCHS):

    total_loss_g, total_loss_d = 0.0, 0.0
    for x, _ in dataloader:
        # x is sampled from data generating distribution x ~ p_data
        x = x.to(device)

        # z is sampled from noise prior z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1
        D_x = discriminator(x)
        D_G_z = discriminator(generator(z))

        # update descriminator by ascending its stochastic gradient
        optimizer_d.zero_grad()
        loss_d = criterion_d(D_x, D_G_z)
        loss_d.backward()
        optimizer_d.step()
        
        # z is sampled from noise prior
        # z ~ p_noise
        z = torch.rand(size=(x.shape[0], DIM_NOISE), device=device) * 2 - 1
        D_G_z = discriminator(generator(z))

        # update generator by descending its stochastic gradient
        optimizer_g.zero_grad()
        loss_g = criterion_g(D_G_z)
        loss_g.backward()
        optimizer_g.step()

        total_loss_d += loss_d.item() * x.shape[0]
        total_loss_g += loss_g.item() * z.shape[0]
    
    
    losses_d.append(total_loss_d / N_samples)
    losses_g.append(total_loss_g / N_samples)

    if VERBOSE: 
        print(
            f'epoch: {epoch}\t' 
            f'generator loss: {(total_loss_g/N_samples):.4f}\t'
            f'discriminator loss: {(total_loss_d/N_samples):.4f}'
        )

    if PLOTTING:
        G_z = generator(Z)
        fig, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
        ax = ax.flatten()
        for i in range(N_ROWS * N_COLS):
            img = G_z[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
            ax[i].imshow(img, cmap='gray')
            ax[i].axis('off')
        fig.tight_layout()
        fig.savefig(os.path.join(SAVE_LOC, f'mnist_{epoch}'))
        plt.close(fig)
# Out:
# epoch: 0	generator loss: -3.5057	discriminator loss: -0.7437
# epoch: 1	generator loss: -2.5451	discriminator loss: -0.6965
# epoch: 2	generator loss: -1.7391	discriminator loss: -0.9118
# epoch: 3	generator loss: -1.4241	discriminator loss: -1.0452
# epoch: 4	generator loss: -1.2230	discriminator loss: -1.1289
# epoch: 5	generator loss: -1.1284	discriminator loss: -1.1853
# epoch: 6	generator loss: -1.0654	discriminator loss: -1.2205
# epoch: 7	generator loss: -1.0340	discriminator loss: -1.2387
# epoch: 8	generator loss: -0.9992	discriminator loss: -1.2598
# epoch: 9	generator loss: -0.9833	discriminator loss: -1.2697
# epoch: 10	generator loss: -0.9883	discriminator loss: -1.2685
# epoch: 11	generator loss: -0.9860	discriminator loss: -1.2713
# epoch: 12	generator loss: -0.9940	discriminator loss: -1.2702
# epoch: 13	generator loss: -1.0043	discriminator loss: -1.2638
# epoch: 14	generator loss: -1.0024	discriminator loss: -1.2685
# epoch: 15	generator loss: -1.0220	discriminator loss: -1.2589
# epoch: 16	generator loss: -1.0321	discriminator loss: -1.2531
# epoch: 17	generator loss: -1.0372	discriminator loss: -1.2507
# epoch: 18	generator loss: -1.0685	discriminator loss: -1.2413
# epoch: 19	generator loss: -1.0653	discriminator loss: -1.2368
# epoch: 20	generator loss: -1.0780	discriminator loss: -1.2327
# epoch: 65	generator loss: -1.3408	discriminator loss: -1.1300
# epoch: 66	generator loss: -1.3261	discriminator loss: -1.1372
# epoch: 67	generator loss: -1.3260	discriminator loss: -1.1407
# epoch: 68	generator loss: -1.3100	discriminator loss: -1.1441
# epoch: 69	generator loss: -1.3422	discriminator loss: -1.1305
# epoch: 70	generator loss: -1.3308	discriminator loss: -1.1371
# epoch: 71	generator loss: -1.3290	discriminator loss: -1.1434
# epoch: 72	generator loss: -1.3070	discriminator loss: -1.1490
# epoch: 73	generator loss: -1.3221	discriminator loss: -1.1410
# epoch: 74	generator loss: -1.3303	discriminator loss: -1.1406
# epoch: 75	generator loss: -1.3297	discriminator loss: -1.1445
# epoch: 76	generator loss: -1.3269	discriminator loss: -1.1409
# epoch: 77	generator loss: -1.3343	discriminator loss: -1.1387
# epoch: 78	generator loss: -1.3288	discriminator loss: -1.1424
# epoch: 79	generator loss: -1.3324	discriminator loss: -1.1440
# epoch: 80	generator loss: -1.3458	discriminator loss: -1.1368
# epoch: 81	generator loss: -1.3489	discriminator loss: -1.1294
# epoch: 82	generator loss: -1.3456	discriminator loss: -1.1289
# epoch: 83	generator loss: -1.3467	discriminator loss: -1.1334
# epoch: 84	generator loss: -1.3356	discriminator loss: -1.1367
# epoch: 85	generator loss: -1.3215	discriminator loss: -1.1434
# epoch: 86	generator loss: -1.3436	discriminator loss: -1.1363
# epoch: 87	generator loss: -1.3413	discriminator loss: -1.1293
# epoch: 88	generator loss: -1.3355	discriminator loss: -1.1345
# epoch: 89	generator loss: -1.3318	discriminator loss: -1.1335
# epoch: 90	generator loss: -1.3380	discriminator loss: -1.1372
# epoch: 91	generator loss: -1.3464	discriminator loss: -1.1297
# epoch: 92	generator loss: -1.3351	discriminator loss: -1.1322
# epoch: 93	generator loss: -1.3227	discriminator loss: -1.1406
# epoch: 94	generator loss: -1.3405	discriminator loss: -1.1363
# epoch: 95	generator loss: -1.3415	discriminator loss: -1.1335
# epoch: 96	generator loss: -1.3457	discriminator loss: -1.1331
# epoch: 97	generator loss: -1.3334	discriminator loss: -1.1326
# epoch: 98	generator loss: -1.3364	discriminator loss: -1.1375
# epoch: 99	generator loss: -1.3479	discriminator loss: -1.1293

# %% [markdown]
# #### GAN Training Losses

# %%
_, ax = plt.subplots()
ax.plot(np.arange(len(losses_g)), losses_g, label='Generator loss')
ax.plot(np.arange(len(losses_d)), losses_d, label='Discriminator loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Generating Fake Data

# %%
Z = torch.rand(size=(N_ROWS * N_COLS, DIM_NOISE), device=device) * 2 - 1
data_fake = generator(Z)

_, ax = plt.subplots(nrows=N_ROWS, ncols=N_COLS, figsize=FIGSIZE)
ax = ax.flatten()
for i in range(N_ROWS * N_COLS):
    img = data_fake[i].cpu().detach().numpy().reshape(IMAGE_SHAPE)
    ax[i].imshow(img, cmap='gray')
    ax[i].set_xticks([]),
    ax[i].set_yticks([])
plt.tight_layout()
plt.show()
